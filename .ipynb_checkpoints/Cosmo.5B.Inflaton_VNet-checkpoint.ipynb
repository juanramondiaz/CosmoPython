# %% [markdown]
# # COMPUTATIONAL COSMOLOGY
# ---
# This project has been developed for the course Cosmology within the Master’s Degree in Physics at the University of Valencia. Its objective is to demonstrate the use of standard scientific libraries together with specialized astrophysical libraries in computational cosmology. The project applies numerical and data analysis techniques commonly used in modern cosmological research. It illustrates how these tools can be integrated to model cosmological scenarios and analyze data.

# %% [markdown]
# ### Authors
# - Alejandro Estellés Roig (aesroig@alumni.uv.es)
# - Juan Ramón Díaz Santos (diazjuan@alumni.uv.es)

# %% [markdown]
# # VNet: Deep Learning Model to Predict the Inflaton Potential
#
# ---
#
# ## 1. Model Summary
#
# In this notebook, we developed a **physics-informed Deep Learning framework** to reconstruct or generate inflationary potentials $ V(\phi) $ in a fully differentiable way using PyTorch.
#
# The neural network $ V_\theta(\phi) $ learns a functional representation of the potential that simultaneously satisfies observational constraints:
#
# $
# n_s \simeq 0.965,
# \qquad
# r \lesssim 0.02,
# \qquad
# A_s \simeq 2.1\times10^{-9},
# \qquad
# N_* \in [50,60].
# $
#
# The loss function combines observational fitting terms with physical regularization and smoothness constraints, enforcing the end of inflation through the condition:
#
# $$\epsilon_V(\phi_{\mathrm{end}})=1$$
#
# ---
#
# ## 2. Pipeline Description
#
# 1. Definition of the computational environment, neural architecture, and automatic differentiation for computing
#
# $$
# V'(\phi), \qquad V''(\phi), \qquad \epsilon_V, \qquad \eta_V
# $$
#
# 2. Computation of observables, search for the end-of-inflation field value, and evaluation of the number of e-folds:
#
# $$N = \int H,dt$$
#
# 3. Training of the neural network using a physics-informed loss function.
#
# 4. Validation and visualization of the learned functions
#
# $$
# V(\phi), \quad \epsilon_V(\phi), \quad \eta_V(\phi).
# $$
#
# 5. Refinement using **L-BFGS optimization**, checkpoint saving, and automatic figure generation.
#
# The training process is **fully differentiable**, enabling direct optimization over physical observables without relying on analytical approximations of the inflationary potential.
#
# ---
#
# ## 3. Physical Interpretation of Results
#
# ### Slow-roll regime
#
# The trained model generates regions where the slow-roll conditions are satisfied:
#
# $$\epsilon_V \ll 1\qquad|\eta_V| \ll 1$$
#
# ensuring a sustained quasi–de Sitter expansion.
#
# ---
#
# ### End of inflation
#
# The learned potential naturally produces a field value $ \phi_{\text{end}} $ such that:
#
# $
# \epsilon_V \approx 1
# $
#
# indicating a dynamical exit from the inflationary phase without imposing an artificial cutoff.
#
# ---
#
# ### Number of e-folds
#
# Typical integrations yield:
#
# $
# N_* \simeq 50\text{–}60
# $
#
# consistent with reheating scenarios and horizon-scale constraints.
#
# ---
#
# ### Observables consistency
#
# The predicted cosmological observables:
#
# $
# (n_s,; r,; A_s)
# $
#
# converge to values compatible with **Planck 2018** and **BICEP/Keck** bounds, remaining within current observational confidence intervals.
#
# ---
#
# ## 4. Conceptual interpretation
#
# The neural parametrization effectively learns a **family of smooth plateau-like potentials**, structurally similar to:
#
# * $\alpha$-attractors
# * Starobinsky-type models
# * hilltop potentials with flat regions
#
# while maintaining sufficient flexibility to capture deviations beyond analytic templates.
#
# From the effective field theory perspective, the network is learning an implicit functional basis:
#
# $
# V_\theta(\phi) \in \mathcal{F}_{\mathrm{EFT}}
# $
#
# regularized by cosmological constraints.
#
# ---
#
# ## 5. Advantages of the VNet approach
#
# ### Functional flexibility
#
# The neural representation avoids assuming a polynomial or exponential ansatz:
#
# $
# V(\phi) \neq \sum_n a_n \phi^n
# $
#
# allowing discovery of novel inflationary potentials.
#
# ---
#
# ### Fully differentiable cosmology
#
# All observables are computed through automatic differentiation:
#
# $
# \frac{dV}{d\phi}, \qquad \frac{d^2V}{d\phi^2}
# $
#
# enabling gradient-based optimization directly on physical quantities.
#
# ---
#
# ### Compatibility with observational constraints
#
# The model enforces:
#
# * amplitude of scalar perturbations
# * spectral tilt
# * tensor-to-scalar ratio
# * duration of inflation
#
# simultaneously during training.
#
# ---
#
# ## 6. Possible extensions
#
# ### Bayesian inference over potentials
#
# Introduce uncertainty estimation:
#
# $
# p(V(\phi)\mid \text{data})
# $
#
# via variational inference or deep ensembles.
#
# ---
#
# ### Multi-field inflation
#
# Generalize:
#
# $
# V(\phi) \rightarrow V(\phi_1,\phi_2,\dots,\phi_n)
# $
#
# using vector-valued neural architectures.
#
# ---
#
# ### Hamilton-Jacobi formulation
#
# Learn directly:
#
# $
# H(\phi)
# $
#
# instead of $V(\phi)$, improving numerical stability.

# %% [markdown]
# ## 0. Libraries and System Configuration
# ---

# %% [markdown]
# ### 0.1. Libraries
# ---

# %%
import os
import math
import random
import copy
from datetime import datetime
import numpy as np
import torch
import torch.nn as nn
import torch.autograd as autograd
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.swa_utils import AveragedModel, SWALR

import matplotlib.pyplot as plt

# %% [markdown]
# ### 0.2. System Configuration
# ---
# In this section, the parameters and numerical environment are defined:
#
# * The random seed is fixed to ensure reproducibility.
# * The numerical precision is set to `float64`, improving stability when computing higher-order derivatives.
# * The computational device is selected (`CPU` or `GPU`).
# * Calculations are performed in **natural units**, where
#
# $$
# M_{\mathrm{Pl}} = 1
# $$
#
# which simplifies the slow-roll expressions and improves numerical conditioning.

# %%
# Reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

# Device selection (use GPU if available)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Default Numeric Precision (float64)
torch.set_default_dtype(torch.float64)

# Natural units: M_Pl (reduced) = 1
MPL = 1.0

# avoid zero division small constant
EPS = 1e-40

print(f"device={DEVICE}, default_dtype={torch.get_default_dtype()}")
# Out:
# device=cuda, default_dtype=torch.float64

# %% [markdown]
# ## 1. Model
# ---

# %% [markdown]
# ### 1.1 Model Architecture
# ---
# A neural network (MLP) is implemented to represent the inflationary potential:
#
# $$V_\theta(\phi)=\mathrm{softplus}(f_\theta(\phi))+V_{\min}$$
#
# where:
#
# * $f_\theta(\phi)$ is a neural network with smooth activation functions (SiLU or Tanh).
# * **softplus** ensures positivity and smoothness of $V(\phi)$.
# * $V_{\min} \ge 0$ prevents unphysical negative potentials.
#
# This parametrization guarantees continuous derivatives of:
#
# $$
# V(\phi), \qquad V'(\phi), \qquad V''(\phi),
# $$
#
# which are essential for computing slow-roll parameters and inflationary observables.

# %%
class VNet(nn.Module):
    def __init__(self, hidden=128, depth=4, Vmin=0.0, act="silu"):
        super().__init__()
        acts = {
            "silu": nn.SiLU(),
            "tanh": nn.Tanh(),
            "gelu": nn.GELU(),
        }
        activation = acts.get(act, nn.SiLU())

        layers = [nn.Linear(1, hidden), activation]
        for _ in range(depth - 1):
            layers += [nn.Linear(hidden, hidden), activation]
        layers += [nn.Linear(hidden, 1)]  # scalar output f_θ(φ)

        self.net = nn.Sequential(*layers)
        self.softplus = nn.Softplus(beta=1.0)  # β=1 -> smooth and stable shape
        # Non-trainable Vmin (if you want to fix an offset ≥0)
        self.register_buffer("Vmin", torch.tensor(Vmin, dtype=torch.get_default_dtype()))

    def forward(self, phi):
        """
        phi: tensor of shape (N,1) or (1,1)
        return: V(phi) with shape (N,1)
        """
        f = self.net(phi)
        return self.softplus(f) + self.Vmin

# %% [markdown]
# ### 1.2. Automatic differentiation and slow-roll parameters
# ---
# Auxiliary functions based on **PyTorch Autograd** are defined:
#
# * `grad_y(y,x)` computes derivatives
#
# $$
# \frac{dy}{dx}
# $$
#
# while preserving the computational graph, enabling higher-order derivatives.
#
# The slow-roll parameters are obtained from the potential:
#
# $$\epsilon_V = \frac12\left(\frac{V'}{V}\right)^2
# \qquad
# \eta_V = \frac{V''}{V}
# $$
# The inflationary observables evaluated at the pivot scale $\phi_\star$ are:
#
# $$n_s = 1 - 6\epsilon_V + 2\eta_V
# \quad
# r = 16\epsilon_V
# \quad
# A_s = \frac{V}{24\pi^2 \epsilon_V}
# $$
#
# ### Physical interpretation
#
# The neural network defines a differentiable functional mapping:
#
# $$
# \phi \mapsto V_\theta(\phi),
# $$
#
# whose derivatives determine the inflationary dynamics through the slow-roll hierarchy.
#
# Because cosmological observables depend on ratios of derivatives of the potential, numerical smoothness is critical. The combination of:
#
# * smooth activations,
# * softplus output constraint,
# * double precision,
# * automatic differentiation,
#
# ensures stable evaluation of:
#
# $$
# \epsilon_V,\quad \eta_V,\quad n_s,\quad r,\quad A_s,
# $$
#
# without requiring an explicit analytic ansatz for the inflationary potential.

# %%
def grad_y(y, x):
    ones = torch.ones_like(y)
    grad = torch.autograd.grad(
        y, x, grad_outputs=ones,
        create_graph=True,
        retain_graph=True,
        allow_unused=True  
    )[0]
    if grad is None:
        grad = torch.zeros_like(x)  # in case of disconnection, avoids NaN
    return grad


def slow_roll_params_from_V(V, phi):
    """
    Computes SR parameters (ε_V, η_V) from V(φ) in units with M_Pl=1:
      ε_V = 1/2 * (V'/V)^2
      η_V = V''/V
    """
    if not phi.requires_grad:
        phi = phi.clone().detach().requires_grad_(True)
    Vp  = grad_y(V,  phi)
    Vpp = grad_y(Vp, phi)
    eps = 0.5 * (Vp / (V + EPS))**2
    eta = (Vpp / (V + EPS))
    return eps, eta


def observables_from_V(model, phi_star):
    """
    Observables at φ*:
      n_s = 1 - 6 ε_V + 2 η_V
      r   = 16 ε_V
      A_s = V / (24 π^2 ε_V)   (with M_Pl = 1)
    Returns scalar tensors (without batch).
    """
    phi_star = phi_star.reshape(1, 1).requires_grad_(True)
    Vstar = model(phi_star)                          # V(φ*)
    eps, eta = slow_roll_params_from_V(Vstar, phi_star)
    ns = 1.0 - 6.0 * eps + 2.0 * eta
    r  = 16.0 * eps
    As = Vstar / (24.0 * math.pi**2 * (eps + EPS))

    # Remove trivial dimensions
    return ns.squeeze(), r.squeeze(), As.squeeze(), Vstar.squeeze()

# %%
def step_slowroll_phi(model, phi, dN):
    """Explicit step in N:  φ_{n+1} = φ_n - (V'/V) dN   (Mpl=1)"""
    phi = phi.clone().requires_grad_(True)
    V   = model(phi)
    Vp  = torch.autograd.grad(V, phi, torch.ones_like(V), create_graph=True)[0]
    dphi = - (Vp / (V + EPS)) * dN
    return (phi + dphi).detach()  # we return a detached tensor for the iteration


def epsilon_from_phi(model, phi):
    phi = phi.clone().requires_grad_(True)
    V   = model(phi)
    Vp  = torch.autograd.grad(V, phi, torch.ones_like(V), create_graph=True)[0]
    eps = 0.5 * (Vp/(V + EPS))**2
    return eps.squeeze()


def integrate_profile_eps(model, phi_star, N_total=60.0, dN=0.25):
    """
    Integrates φ(N) in slow-roll and returns tensors:
      N_grid [K], eps_grid [K], H_grid [K], phi_grid [K]
    Keeps gradients with respect to model parameters through epsilon (not through the whole loop).
    """
    K = int(N_total / dN) + 1
    N_grid   = torch.linspace(0.0, N_total, K, device=DEVICE)
    phi_grid = [phi_star.reshape(1,1)]
    eps_list = []
    H_list   = []

    phi = phi_grid[0]
    for k in range(K):
        eps = epsilon_from_phi(model, phi)
        V   = model(phi)
        H   = torch.sqrt(V/3.0 + EPS)
        eps_list.append(eps)
        H_list.append(H.squeeze())
        # stop if it already ended (ε≈1); for the rest fill with ε=1 and keep sizes
        if eps.item() >= 1.0 and k < K-1:
            # fill the rest (without gradient) to avoid NaNs
            rem = K - k - 1
            eps_list += [torch.tensor(1.0, device=DEVICE)] * rem
            H_list   += [H.squeeze().detach()] * rem
            break
        # next φ step
        phi = step_slowroll_phi(model, phi, dN)

    eps_grid = torch.stack([e if torch.is_tensor(e) else torch.tensor(e, device=DEVICE) for e in eps_list])
    H_grid   = torch.stack([h if torch.is_tensor(h) else torch.tensor(h, device=DEVICE) for h in H_list])
    # If it stopped early, N_grid remains complete; eps_grid may be shorter → adjust
    if eps_grid.shape[0] < K:
        Kcur = eps_grid.shape[0]
        N_grid = N_grid[:Kcur]
        H_grid = H_grid[:Kcur]
    return N_grid, eps_grid, H_grid, torch.cat(phi_grid)

# %%
def eps_target_profile(N_grid, N_t=50.0, dN_width=3.0, eps0=1e-3):
    """
    ε_target(N) = eps0 + (1-eps0) * sigmoid((N - N_t)/dN_width)
    """
    x = (N_grid - N_t) / dN_width
    sig = 1.0 / (1.0 + torch.exp(-x))
    return eps0 + (1.0 - eps0) * sig

# %% [markdown]
# ### 1.3. Loss Profile
# ---

# %%
def profile_loss(model, phi_star, N_t=50.0, dN_width=3.0, eps0=1e-3, N_total=60.0, dN=0.25):
    N_grid, eps_grid, H_grid, _ = integrate_profile_eps(model, phi_star, N_total=N_total, dN=dN)
    eps_tgt = eps_target_profile(N_grid, N_t=N_t, dN_width=dN_width, eps0=eps0)

    # 1) MSE with the target profile
    L_mse = torch.mean((eps_grid - eps_tgt)**2)

    # 2) "N_end" close to N_t: first index with ε>=1
    mask_end = (eps_grid >= 1.0 - 1e-3)
    if mask_end.any():
        idx_end = torch.nonzero(mask_end, as_tuple=False)[0,0]
        N_end   = N_grid[idx_end]
        L_end   = (N_end - N_t).abs()
    else:
        # if it does not reach 1, penalize strongly
        L_end = torch.tensor(5.0, device=DEVICE)

    # 3) Low H variation before N_t (plateau smoothness): d ln H / dN = -ε ~ 0
    # we penalize the relative variance of H in [0, N_t]
    mask_pre = (N_grid <= N_t)
    if mask_pre.any():
        H_pre  = H_grid[mask_pre]
        L_Hflat = torch.var(H_pre / (H_pre.mean() + EPS))
    else:
        L_Hflat = torch.tensor(0.0, device=DEVICE)

    return L_mse + 0.5*L_end + 0.1*L_Hflat, {
        "L_mse": L_mse.detach().item(),
        "L_end": L_end.detach().item(),
        "L_Hflat": L_Hflat.detach().item()
    }

# %% [markdown]
# ## 2. Observables Test
# ---

# %% [markdown]
# ### 2.1. Model instance and Observables
# ---

# %%
VNET_HIDDEN     = 128
VNET_DEPTH      = 4
VNET_VMIN       = 0.0
VNET_ACTIVATION = "silu"

model = VNet(
    hidden=VNET_HIDDEN,
    depth=VNET_DEPTH,
    Vmin=VNET_VMIN,
    act=VNET_ACTIVATION,
   # fourier_features=True,
   # n_freqs=8,
   # spectral_norm=True
).to(DEVICE)


# Start point φ* (in M_Pl units)
phi_star = torch.tensor([5.0], dtype=torch.float64, device=DEVICE)
phi_star = phi_star.reshape(1, 1).clone().detach().requires_grad_(True)

# Observables (n_s, r, A_s, V(φ*))
ns, r, As, Vstar = observables_from_V(model, phi_star)

print(f"φ*={phi_star.item():.3f}")
print(f"n_s={ns.item():.5f},  r={r.item():.5f},  A_s={As.item():.3e},  V(φ*)={Vstar.item():.3e}")
# Out:
# φ*=5.000
# n_s=1.00091,  r=0.00166,  A_s=2.675e+01,  V(φ*)=6.593e-01

# %% [markdown]
# ### 2.2. End of inflation
# ---

# %%
def find_phi_end(model, phi_start, step=0.01, max_steps=20000):
    """
    Searches for φ_end such that ε_V(φ_end) ≈ 1.
    Starts at phi_start and moves in steps of size 'step'
    until ε_V ≥ 1 (end condition).
    """
    phi = phi_start.clone().detach().reshape(1, 1).to(DEVICE)
    direction = -1.0  # we move "downward" in φ (typical in inflation)
    for _ in range(max_steps):
        phi.requires_grad_(True)
        V = model(phi)
        eps, _ = slow_roll_params_from_V(V, phi)
        if eps.item() >= 1.0:
            return phi.detach().clone()
        phi = (phi + direction * step).detach()
    return None  # if not found (random initial parameters)

# %% [markdown]
# ### 2.3. Number of e-Folds
# ---

# %%
# N_* = ∫ (V / (M_Pl^2 * V')) dφ  from φ_end to φ*

def integrate_N(model, phi_end, phi_star, n_pts=1024):
    """
    Integrates the number of e-folds using trapezoidal quadrature.
    """
    # We generate a uniform grid between φ_end and φ*
    grid = torch.linspace(phi_end.item(), phi_star.item(), n_pts, device=DEVICE).reshape(-1, 1)
    grid.requires_grad_(True)

    Vg = model(grid)
    Vp = grad_y(Vg, grid)
    integrand = Vg / (Vp + EPS)

    # Trapezoidal quadrature
    dphi = torch.abs(grid[1] - grid[0])
    N = 0.5 * torch.sum(integrand[:-1] + integrand[1:]) * dphi / (MPL**2)
    return N.detach().cpu().item()

# %%
# φ_end (end of inflation)
phi_end = find_phi_end(model, phi_start=phi_star, max_steps=200)
if phi_end is None:
    print("φ_end was not found (the initial model does not satisfy ε=1).")
else:
    print(f"φ_end found ≈ {phi_end.item():.3f}")
    Nstar = integrate_N(model, phi_end, phi_star)
    print(f"N_* ≈ {Nstar:.3f} e-folds")
# Out:
# φ_end was not found (the initial model does not satisfy ε=1).

# %% [markdown]
# At this point, the code should:
#
# * Compute $n_s,r,A_s,V(\phi_\star)$ for a random model (arbitrary values, not yet physical).
# * Attempt to locate $\phi_{end}$ where $\varepsilon_V=1$.
# * If it is physically meaningful, integrate $N_\star$.
#
# During the subsequent training, these calculations will become physically consistent, making it possible to impose observational constraints
# $$
# (n_s \approx 0.965; r < 0.03; N_\star \approx 50 - 60).
# $$

# %% [markdown]
# ## 3. Physics-informed loss function
# ---
# **Total loss**:
# $$
# \mathcal{L} = w_{ns}( \hat n_s - n_s^{\rm tgt})^2 + w_{As}( \hat A_s - A_s^{\rm tgt})^2 + w_{N}( \hat N_\star - N_\star^{\rm tgt})^2 + \lambda_{r}\mathrm{ReLU}(\hat r - r_{\max}) + \lambda_{\rm smooth}\langle (V'')^2 \rangle_{\text{window}} + \lambda_{\rm min}|V'(\phi_0)| + \lambda_{\rm phys}\mathrm{ReLU}\big(1-\epsilon_V(\phi_{\rm end})\big)
# $$
#
# - The **MSE terms** enforce that the observables at $\phi_\star$ match the targets:
#   $n_s \simeq 0.965$, $A_s \simeq 2.1\times 10^{-9}$, $N_\star \in [50,60]$.
# - The **hinge term** ensures $r \le r_{\max} $ in a differentiable way: it penalizes only if $\hat r > r_{\max} $.
# - The **smoothness term** $\langle (V'')^2 \rangle$ controls spurious oscillations of the potential.
# - The **anchor minimum** $|V'(\phi_0)|$ helps stabilize a reference region (optional).
# - The **physical penalty** enforces the existence of an end of inflation with $\epsilon_V(\phi_{\rm end})\simeq 1$.
#
# The training loop uses **Adam** (with *scheduler*), *gradient clipping*, and reports key metrics. After convergence, the observables should approach the targets, producing a physically consistent $V(\phi)$.

# %% [markdown]
# ### 3.1. Parameters
# ---

# %%
# ---------- Observational targets ----------
ns_tgt  = torch.tensor(0.965,  device=DEVICE)
As_tgt  = torch.tensor(2.10e-9, device=DEVICE)
N_tgt   = torch.tensor(55.0,    device=DEVICE)
r_max   = torch.tensor(0.02,    device=DEVICE)  # we use hinge: r <= r_max

# ---------- Observable weights and reg. ----------
w_ns, w_As, w_N = 1.0, 5.0, 0.2          # MSE (n_s, A_s, N_*)
lam_rhinge      = 1.0                    # penalty for exceeding r_max
lam_smooth      = 1e-2                   # ∫ (V'')^2 in window near φ*
lam_min         = 1e-2                   # |V'(φ0)| to enforce a smooth minimum (optional)
lam_phys        = 4e-1                   # ReLU(1 - ε(φ_end)) (enforce ε=1 at end of inflation)
lam_obs         = 1e-1  

lambda_prof = 5e-1   # range [0.2 - 2.0]
lambda_mon = 3e-1   # range [0.2 - 2.0]
lambda_obs = 1.0

# ---------- Windows and grids for regularization ----------
win_radius   = 2.0    # window around φ* for smoothness
win_points   = 256    # points for the smoothness integral
phi0_anchor  = 0.0    # point (optional) where we enforce small gradient

# %% [markdown]
# ### 3.2. Loss Physics
# ---

# %%
def loss_physics(model, phi_star, max_steps=2000):
    """
    Computes the total loss and also returns a dictionary with internal metrics.
    Components:
      - MSE on (n_s, A_s, N_*)
      - Hinge for r:  ReLU(r - r_max)
      - Smoothness: integral (average) of (V'')^2 in a window around φ*
      - Minimum: |V'(φ0)| at an anchor (optional)
      - Physics: ReLU(1 - ε(φ_end))  (enforce ε=1 at end of infl.)
    """
    # 1) Observables at φ*
    ns_hat, r_hat, As_hat, Vstar = observables_from_V(model, phi_star)

    # 2) End of inflation
    phi_end = find_phi_end(model, phi_start=phi_star, max_steps=max_steps)
    if phi_end is None:
        # if not found, penalize strongly and use N=0 to avoid NaNs
        N_hat = torch.tensor(0.0, device=DEVICE)
        loss_phys = torch.tensor(lam_phys * 10.0, device=DEVICE)
    else:
        # Integrate N_* and penalize if ε(φ_end) != 1
        N_hat = torch.tensor(integrate_N(model, phi_end, phi_star), device=DEVICE)
        phi_end = phi_end.reshape(1,1).requires_grad_(True)
        V_end = model(phi_end)
        eps_end, _ = slow_roll_params_from_V(V_end, phi_end)
        loss_phys = lam_phys * torch.relu(1.0 - eps_end.squeeze())

    # 3) Smoothness regularization: average of (V'')^2 in window [φ*-R, φ*+R]
    phi_left  = (phi_star.detach().item() - win_radius)
    phi_right = (phi_star.detach().item() + win_radius)
    grid = torch.linspace(phi_left, phi_right, win_points, device=DEVICE).reshape(-1,1)
    grid.requires_grad_(True)
    Vg   = model(grid)
    Vp_g = grad_y(Vg, grid)
    Vpp_g= grad_y(Vp_g, grid)
    smooth_reg = (Vpp_g**2).mean()

    # 4) Nearby minimum (optional): enforce gradient ~0 at φ = φ0_anchor
    phi0 = torch.tensor([[phi0_anchor]], dtype=torch.get_default_dtype(), device=DEVICE, requires_grad=True)
    V0   = model(phi0)
    Vp0  = grad_y(V0, phi0)
    min_reg = Vp0.abs().mean()

    # 5) MSE of observables
    loss_obs = ( w_ns*(ns_hat - ns_tgt)**2
               + w_As*(As_hat - As_tgt)**2
               + w_N *(N_hat  - N_tgt)**2 )

    # 6) Hinge for r <= r_max
    loss_r_hinge = lam_rhinge * torch.relu(r_hat - r_max)

    # 7) Total
    total = lam_obs*loss_obs + loss_r_hinge + lam_smooth*smooth_reg + lam_min*min_reg + loss_phys

    metrics = {
        'loss_total': total.detach().item(),
        'loss_obs':   loss_obs.detach().item(),
        'loss_r':     loss_r_hinge.detach().item(),
        'smooth':     smooth_reg.detach().item(),
        'min_reg':    min_reg.detach().item(),
        'loss_phys':  loss_phys.detach().item(),
        'ns':         ns_hat.detach().item(),
        'r':          r_hat.detach().item(),
        'As':         As_hat.detach().item(),
        'N':          N_hat.detach().item() if isinstance(N_hat, torch.Tensor) else float(N_hat),
        'phi_star':   phi_star.detach().item()
    }
    return total, metrics

# %% [markdown]
# ### 3.3. Extended Loss Physics
# ---

# %%
def loss_monotonicity(model, phi_min=0.0, phi_max=6.0, n_pts=200):
    phi = torch.linspace(phi_min, phi_max, n_pts, device=DEVICE).reshape(-1,1).requires_grad_(True)
    V = model(phi)
    Vp = torch.autograd.grad(V, phi, grad_outputs=torch.ones_like(V),
                             create_graph=True, retain_graph=True)[0]
    neg_part = torch.relu(-Vp)     # only if V'<0
    loss_mon = torch.mean(neg_part**2)
    return loss_mon


def loss_physics_total(model, phi_star, max_steps=200):
    # previous loss (observables + regularizers)
    L_obs, metrics = loss_physics(model, phi_star, max_steps=200)
    L_mon = loss_monotonicity(model, 0.0, 6.0, n_pts=256)

    # new profile loss
    L_prof, mprof = profile_loss(model, phi_star, N_t=50.0, dN_width=3.0, eps0=1e-3, N_total=60.0, dN=0.25)

    total = lambda_obs*L_obs + lambda_prof * L_prof + lambda_mon * L_mon
    metrics.update({
        "L_mon": L_mon.detach().item(),
        "L_prof": L_prof.detach().item(),
        "L_prof_mse": mprof["L_mse"],
        "L_prof_end": mprof["L_end"],
        "L_prof_Hflat": mprof["L_Hflat"],
    })
    return total, metrics

# %% [markdown]
# ## 4. Training
# ---

# %% [markdown]
# ### 4.1. Training Loop Base
# ---

# %%
def loop_train_1():
    # -------------- Training --------------
    max_iters      = 1000
    print_every    = 100
    grad_clip_norm = 5.0     # for stability
    
    for it in range(1, max_iters+1):
        opt.zero_grad()
        total_loss, metrics = loss_physics_total(model, phi_star, max_steps=10000)
        total_loss.backward()
    
        # gradient clipping to avoid explosion
        torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip_norm)
        torch.nn.utils.clip_grad_norm_([phi_star], grad_clip_norm)
    
        opt.step()
        scheduler.step()
    
        if it % print_every == 0 or it == 1:
            print(f"[{it:4d}] L={metrics['loss_total']:.3e} | "
                  f"ns={metrics['ns']:.4f} r={metrics['r']:.4f} "
                  f"As={metrics['As']:.2e} N={metrics['N']:.2f} | "
                  f"obs={metrics['loss_obs']:.2e} rh={metrics['loss_r']:.2e} "
                  f"smooth={metrics['smooth']:.2e} min={metrics['min_reg']:.2e} phys={metrics['loss_phys']:.2e} "
                  f"| φ*={metrics['phi_star']:.2f}")

# %% [markdown]
# ### 4.2. Optimizer
# ---

# %%
base_lr = 3e-3
max_iters = 1000

optimizer = optim.AdamW(model.parameters(), lr=base_lr, weight_decay=1e-4)

scheduler = optim.lr_scheduler.OneCycleLR(
    optimizer,
    max_lr=base_lr,
    total_steps=max_iters,
    pct_start=0.2,
    anneal_strategy='cos',
    div_factor=10,
    final_div_factor=1e2
)

# %% [markdown]
# ### 4.3. Scaler
# ---

# %%
# We create a "shadow" of the current model parameters
swa_shadow = {k: v.detach().clone() for k, v in model.state_dict().items()}
swa_n = 0  # SWA iteration counter

@torch.no_grad()
def update_swa_shadow(swa_shadow, model, swa_n):
    """Manually averages the model weights without deepcopy or reconstruction."""
    for k, v in model.state_dict().items():
        swa_shadow[k].mul_(swa_n / (swa_n + 1.0)).add_(v.detach() / (swa_n + 1.0))
    return swa_n + 1

@torch.no_grad()
def apply_swa_shadow(model, swa_shadow):
    """Applies the averaged shadow weights to the model."""
    model.load_state_dict(swa_shadow)


swa_start = int(0.8 * max_iters)   # start averaging at 80% of training
swa_scheduler = SWALR(optimizer, swa_lr=1e-4)

scaler = torch.cuda.amp.GradScaler(enabled=torch.cuda.is_available())

# %% [markdown]
# ### 4.4. Main Training Loop
# ---

# %%
# ============================================================
# Main Training Loop
# ============================================================

for it in range(1, max_iters + 1):
    optimizer.zero_grad(set_to_none=True)
    
    with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
        # loss function
        L, metrics = loss_physics_total(model, phi_star, max_steps=2000)
        
    scaler.scale(L).backward()

    # Scaler to avoid gradient explosion due to second order derivatives
    scaler.unscale_(optimizer)
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

    scaler.step(optimizer)
    scaler.update()

    # Schedulers
    if it > swa_start:
        swa_n = update_swa_shadow(swa_shadow, model, swa_n)
    else:
        scheduler.step()
    
    # Logging
    if it % 25 == 0 or it == 1:
        print(f"[{it:4d}] L={metrics['loss_total']:.3e} | "
              f"obs={metrics['loss_obs']:.2e} | r={metrics['loss_r']:.2e} | "
              f"smooth={metrics['smooth']:.2e} | phys={metrics['loss_phys']:.2e} | "
              f"prof={metrics['L_prof']:.2e} | mono={metrics['L_mon']:.2e} | \n\t"
              f"As={metrics['As']:.2e} N={metrics['N']:.2f} | "
              f"ns={metrics['ns']:.4f} | r={metrics['r']:.4f}")
# Out:
# [   1] L=4.223e+02 | obs=4.18e+03 | r=0.00e+00 | smooth=2.77e-07 | phys=4.00e+00 | prof=2.62e+00 | mono=7.10e-05 |
# 	As=2.67e+01 N=0.00 | ns=1.0009 | r=0.0017

# %% [markdown]
# ### 4.5. Final training process
# ---

# %%
# ============================================================
# Final Average (SWA)
# ============================================================

torch.optim.swa_utils.update_bn(
    torch.linspace(0, 8, 128).reshape(-1, 1).to(DEVICE), model
)
final_model = model
print("Training Finished.")
# Out:
# Training Finished.

# %% [markdown]
# ## 5. Results
# ---

# %% [markdown]
# ### 5.1. Save and Load of Trained Model
# ---

# %%
SAVE_PATH = "./V_inflaton_DL_3.pt"

def model_save(path):
    torch.save({
        'model_state_dict': model.state_dict(),
        'phi_star': phi_star.detach().cpu(),
        'config': {
            'hidden': VNET_HIDDEN,
            'depth': VNET_DEPTH,
            'Vmin': VNET_VMIN,
            'act': VNET_ACTIVATION,
            #'fourier_features': True,
            #'n_freqs': 8,
            #'spectral_norm': True
        }
    }, path)
    
    print(f"Model saved in file: {path}")
model_save(SAVE_PATH)
# Out:
# Model saved in file: ./V_inflaton_DL_3.pt

# %%
def load_model(model_file, device = DEVICE):
    if os.path.exists(model_file): 
        print('EXISTS', model_file)
    else:
        print('NOT EXISTS', model_file)
              
    checkpoint = torch.load(model_file, map_location="cpu")
    model = VNet(hidden=checkpoint['config']['hidden'],
                depth=checkpoint['config']['depth'],
                Vmin=checkpoint['config']['Vmin'],
                act=checkpoint['config']['act'],
                #fourier_features=checkpoint['config']['fourier_features'],
                #n_freqs=checkpoint['config']['n_freqs'],
                #spectral_norm=checkpoint['config']['spectral_norm']
                               )
    model.load_state_dict(checkpoint['model_state_dict'])
    model = model.double()
    model.eval()
    model.to(device)
    return model

# %% [markdown]
# ### 5.2. Diagnostics
# ---

# %%
def slowroll_from_model(model, phi_grid):
    """Returns V, V', V'', ε_V, η_V on a set of φ."""
    phi_grid = phi_grid.reshape(-1, 1).to(next(model.parameters()).device)
    phi_grid.requires_grad_(True)
    
    V = model(phi_grid)
    Vp = torch.autograd.grad(V.sum(), phi_grid, create_graph=True)[0]
    Vpp = torch.autograd.grad(Vp.sum(), phi_grid, create_graph=True)[0]

    eps = 0.5 * (Vp / (V + 1e-40))**2
    eta = Vpp / (V + 1e-40)
    return phi_grid.detach(), V.detach(), Vp.detach(), Vpp.detach(), eps.detach(), eta.detach()


# ============================================================
# Evaluation on a φ grid
# ============================================================
model_file = "./V_inflaton_DL_3.pt"
model = load_model(model_file)
phi_min, phi_max = -8.0, 8.0
N_points = 400

phi_grid = torch.linspace(phi_min, phi_max, N_points, dtype=torch.float64, device=DEVICE)
phi, V, Vp, Vpp, eps, eta = slowroll_from_model(model, phi_grid)

phi, V, Vp, Vpp, eps, eta = [x.cpu().numpy().squeeze() for x in (phi, V, Vp, Vpp, eps, eta)]

# ============================================================
# Physical diagnostic plots
# ============================================================

plt.figure(figsize=(14, 10))

# --- (1) Potential V(φ)
plt.subplot(2,2,1)
plt.plot(phi, V, lw=2)
plt.title(r"$V(\phi)$ — Inflationary potential", fontsize=14)
plt.xlabel(r"$\phi / M_{Pl}$")
plt.ylabel(r"$V(\phi)$")
plt.grid(True, alpha=0.3)

# --- (2) Derivatives
plt.subplot(2,2,2)
plt.plot(phi, Vp, label=r"$V'(\phi)$", lw=2)
plt.plot(phi, Vpp, label=r"$V''(\phi)$", lw=2, ls='--')
plt.xlabel(r"$\phi / M_{Pl}$")
plt.ylabel(r"Derivatives of $V(\phi)$")
plt.title("Potential derivatives")
plt.legend()
plt.grid(True, alpha=0.3)

# --- (3) Slow-roll parameters ε_V, η_V
plt.subplot(2,2,3)
plt.plot(phi, eps, label=r"$\varepsilon_V$", lw=2)
plt.plot(phi, eta, label=r"$\eta_V$", lw=2, ls='--')
plt.axhline(1, color='r', ls=':', lw=1.5, label=r"$\varepsilon_V = 1$")
plt.xlabel(r"$\phi / M_{Pl}$")
plt.ylabel("Slow-roll parameters")
plt.yscale("log")
plt.title("Inflation regime")
plt.legend()
plt.grid(True, which='both', alpha=0.4)

# --- (4) ε vs η phase plane
plt.subplot(2,2,4)
plt.plot(eta, eps, 'b', lw=2)
plt.xlabel(r"$\eta_V$")
plt.ylabel(r"$\varepsilon_V$")
plt.title("Slow-roll phase plane")
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# EXISTS ./V_inflaton_DL_3.pt

# %% [markdown]
# ### 5.3. State Summary
# ---

# %%
def epsilon_eta_profile(model, phi_min, phi_max, n_pts=501, device=DEVICE):
    """
    Returns profiles of V, ε, η on a uniform φ grid.
    """
    grid = torch.linspace(phi_min, phi_max, n_pts, device=device).reshape(-1, 1)
    grid.requires_grad_(True)
    Vg   = model(grid)
    Vp   = grad_y(Vg, grid)
    Vpp  = grad_y(Vp, grid)
    eps  = 0.5 * (Vp / (Vg + EPS))**2
    eta  = (Vpp / (Vg + EPS))
    return grid.detach().cpu().numpy().ravel(), \
           Vg.detach().cpu().numpy().ravel(), \
           eps.detach().cpu().numpy().ravel(), \
           eta.detach().cpu().numpy().ravel()

def summarize_state(model, phi_star, verbose=True):
    """
    Summarizes observables, φ_end and N_* with readable output.
    """
    ns_hat, r_hat, As_hat, V_star = observables_from_V(model, phi_star)
    phi_end = find_phi_end(model, phi_start=phi_star)

    if phi_end is not None:
        N_hat = integrate_N(model, phi_end, phi_star)
        phi_end = phi_end.reshape(1,1).clone().detach().requires_grad_(True)
        V_end = model(phi_end)
        eps_end, _ = slow_roll_params_from_V(V_end, phi_end)
        #eps_end, _ = slow_roll_params_from_V(model(phi_end.reshape(1,1)), phi_end.reshape(1,1))
        eps_end_val = eps_end.detach().item()
    else:
        N_hat = float('nan')
        eps_end_val = float('nan')

    if verbose:
        print("=== STATE SUMMARY ===")
        print(f"φ*     = {phi_star.item():.6f}")
        print(f"V(φ*)  = {V_star.item():.6e}")
        print(f"n_s    = {ns_hat.item():.6f}")
        print(f"r      = {r_hat.item():.6f}")
        print(f"A_s    = {As_hat.item():.3e}")
        print(f"φ_end  = {('None' if phi_end is None else f'{phi_end.item():.6f}')}")
        print(f"ε(φ_end)≈ {eps_end_val:.6f}")
        print(f"N_*    ≈ {N_hat:.3f}")
    return {
        "phi_star": phi_star.detach().item(),
        "V_star":   V_star.detach().item(),
        "ns":       ns_hat.detach().item(),
        "r":        r_hat.detach().item(),
        "As":       As_hat.detach().item(),
        "phi_end":  (None if phi_end is None else phi_end.detach().item()),
        "eps_end":  eps_end_val,
        "N_star":   N_hat
    }

summary = summarize_state(model, phi_star)
# Out:
# === STATE SUMMARY ===
# φ*     = 5.000000
# V(φ*)  = 4.205747e-01
# n_s    = 1.018297
# r      = 0.050681
# A_s    = 5.605e-01
# φ_end  = None
# ε(φ_end)≈ nan
# N_*    ≈ nan

# %% [markdown]
# ### 5.4 — Validation and plots
# ---
# * *plot_all* draws:
#
#   1. $V(\phi)$ with markers at $\phi_* $ and $\phi_{\text{end}} $.
#   2. $\epsilon_V(\phi) $ (log scale) and the line $\epsilon_V=1 $ to visualize the end of inflation.
#   3. $\eta_V(\phi) $ with a reference at 0.
#
# These routines make it possible to diagnose whether the learned potential is **smooth**, **physically consistent**, and **compatible** with a prolonged slow-roll regime and a well-defined end of inflation.
#
# * In plot_all, if phi_end falls outside the window, the vertical line for $\phi_{end}$ is not drawn.
# * Increase the pad to capture it.

# %%
def plot_all(model, phi_star, pad=3.0, n_pts=601, save_prefix=None, device=DEVICE):
    """
    Plots V(φ), ε(φ), η(φ) in a window around φ* and marks φ* and φ_end.
    """
    # Find φ_end to mark on plots
    phi_end = find_phi_end(model, phi_start=phi_star)
    # Plot window
    phi_left  = phi_star.item() - pad
    phi_right = phi_star.item() + pad

    # Profiles
    phis, Vvals, epsvals, etavals = epsilon_eta_profile(model, phi_left, phi_right, n_pts=n_pts, device=device)

    # ---- Plot V(φ) ----
    plt.figure(figsize=(6,4))
    plt.plot(phis, Vvals, lw=2)
    plt.axvline(phi_star.item(), ls='--')
    if phi_end is not None and (phi_left <= phi_end.item() <= phi_right):
        plt.axvline(phi_end.item(), ls=':', lw=2)
    plt.title("Potential $V(\\phi)$")
    plt.xlabel("$\\phi$")
    plt.ylabel("$V(\\phi)$")
    plt.tight_layout()
    if save_prefix: plt.savefig(f"{save_prefix}_V.png", dpi=150)
    plt.show()

    # ---- Plot ε(φ) ----
    plt.figure(figsize=(6,4))
    plt.plot(phis, epsvals, lw=2)
    plt.axhline(1.0, ls='--')  # end of inflation threshold
    plt.axvline(phi_star.item(), ls='--')
    if phi_end is not None and (phi_left <= phi_end.item() <= phi_right):
        plt.axvline(phi_end.item(), ls=':', lw=2)
    plt.yscale("log")  # ε can vary across several decades
    plt.title("Slow-roll parameter $\\epsilon_V(\\phi)$")
    plt.xlabel("$\\phi$")
    plt.ylabel("$\\epsilon_V$")
    plt.tight_layout()
    if save_prefix: plt.savefig(f"{save_prefix}_eps.png", dpi=150)
    plt.show()

    # ---- Plot η(φ) ----
    plt.figure(figsize=(6,4))
    plt.plot(phis, etavals, lw=2)
    plt.axhline(0.0, ls='--', alpha=0.7)
    plt.axvline(phi_star.item(), ls='--')
    if phi_end is not None and (phi_left <= phi_end.item() <= phi_right):
        plt.axvline(phi_end.item(), ls=':', lw=2)
    plt.title("Slow-roll parameter $\\eta_V(\\phi)$")
    plt.xlabel("$\\phi$")
    plt.ylabel("$\\eta_V$")
    plt.tight_layout()
    if save_prefix: plt.savefig(f"{save_prefix}_eta.png", dpi=150)
    plt.show()

plot_all(model, phi_star, pad=3.0, n_pts=601, save_prefix=None)

# %% [markdown]
# ## 6. L-BFGS
# ---

# %% [markdown]
# ### 6.1. L-BFGS refinement
# ---
# * After training with Adam, a refinement step is applied using the quasi-Newton optimizer **L-BFGS**, which is ideal for adjusting smooth local minima of the potential $V(\phi)$.
# * It allows faster convergence in nearly quadratic regions of the physical loss function.

# %%
# --- Saving parameters ---
SAVE_DIR = "./runs"
os.makedirs(SAVE_DIR, exist_ok=True)
timestamp  = datetime.now().strftime("%Y%m%d_%H%M%S")
RUN_ID     = f"run_{timestamp}"
SAVE_PATH  = os.path.join(SAVE_DIR, f"{RUN_ID}.pt")
LBFGS_ITER = 200
# --- 10.1 L-BFGS refinement -----------------------------------
# This phase fine-tunes the model trained by Adam.
optimizer_lbfgs = torch.optim.LBFGS(
    list(model.parameters()) + [phi_star],
    lr=0.8,
    max_iter=LBFGS_ITER,
    max_eval=None,
    history_size=100,
    line_search_fn="strong_wolfe",
    tolerance_grad=1e-8,
    tolerance_change=1e-9,
)

def closure():
    optimizer_lbfgs.zero_grad()
    total_loss, metrics = loss_physics(model, phi_star)
    total_loss.backward()
    if closure.print_counter % 20 == 0:
        print(f"[L-BFGS] iter={closure.print_counter:03d} "
              f"L={metrics['loss_total']:.3e} | n_s={metrics['ns']:.4f} "
              f"r={metrics['r']:.4f} N={metrics['N']:.2f}")
    closure.print_counter += 1
    return total_loss

closure.print_counter = 0
optimizer_lbfgs.step(closure)
print("L-BFGS refinement finished.")
model_save(SAVE_PATH)

summary_final = summarize_state(model, phi_star)
plot_all(model, phi_star, pad=3.0, save_prefix=os.path.join(SAVE_DIR, RUN_ID))
# Out:
# [L-BFGS] iter=000 L=6.469e+01 | n_s=1.0183 r=0.0507 N=0.00
# [L-BFGS] iter=020 L=6.451e+01 | n_s=0.9508 r=0.0206 N=0.00
# L-BFGS refinement finished.
# Model saved in file: ./runs\run_20260322_123353.pt
# === STATE SUMMARY ===
# φ*     = 5.239324
# V(φ*)  = 6.259730e-03
# n_s    = 0.760489
# r      = 0.343719
# A_s    = 1.230e-03
# φ_end  = 0.889324
# ε(φ_end)≈ 1.024696
# N_*    ≈ 51.378

# %% [markdown]
# ### 6.2. L-BFGS Validation
# ---

# %%
# --- Auxiliary functions ---
def V_DL_torch(model, phi):
    """Neural potential V(φ) (torch.Tensor)."""
    if not torch.is_tensor(phi):
        phi = torch.tensor([[phi]], dtype=torch.float64)
    else:
        phi = phi.reshape(-1, 1).to(torch.float64)
    return model(phi)

def V_DL_prime(model, phi):
    """First derivative dV/dφ."""
    phi_t = torch.tensor([[phi]], dtype=torch.float64, requires_grad=True, device = DEVICE)
    V = model(phi_t)
    Vp = torch.autograd.grad(V, phi_t, torch.ones_like(V),
                             create_graph=True, retain_graph=True)[0]
    return Vp.detach().cpu().numpy().ravel()[0]

def V_DL_double_prime(model, phi):
    """Second derivative d²V/dφ²."""
    phi_t = torch.tensor([[phi]], dtype=torch.float64, requires_grad=True, device = DEVICE)
    V = model(phi_t)
    Vp = torch.autograd.grad(V, phi_t, torch.ones_like(V),
                             create_graph=True, retain_graph=True)[0]
    Vpp = torch.autograd.grad(Vp, phi_t, torch.ones_like(Vp),
                              create_graph=True, retain_graph=True)[0]
    return Vpp.detach().cpu().numpy().ravel()[0]

def slowroll_params(model, phi):
    """Computes ε_V and η_V for the neural model."""
    phi_t = torch.tensor([[phi]], dtype=torch.float64, requires_grad=True, device = DEVICE)
    V = model(phi_t)
    Vp = torch.autograd.grad(V, phi_t, torch.ones_like(V),
                             create_graph=True, retain_graph=True)[0]
    Vpp = torch.autograd.grad(Vp, phi_t, torch.ones_like(Vp),
                              create_graph=True, retain_graph=True)[0]
    eps = 0.5 * (Vp / (V + EPS))**2
    eta = Vpp / (V + EPS)
    return eps.detach().item(), eta.detach().item(), V.detach().item()

def H_from_V(model, phi):
    """Hubble approximated by slow-roll: H² ≈ V/3."""
    phi_t = torch.tensor([[phi]], dtype=torch.float64, device = DEVICE)
    V = model(phi_t)
    return np.sqrt(V.detach().cpu().numpy().ravel()[0] / 3.0)

# ================================================================
# Range of φ to evaluate
# ================================================================
phi_vals = torch.linspace(1.0, 6.0, 400, device = DEVICE)

# ================================================================
# Compute V, ε_V, η_V and H(φ)
# ================================================================
V_vals,dV_vals, eps_vals, eta_vals, H_vals = [], [], [], [], []
for phi in phi_vals:
    eps, eta, Vv = slowroll_params(model, phi)
    V_vals.append(Vv)
    dV_vals.append(V_DL_prime(model, phi))
    eps_vals.append(eps)
    eta_vals.append(eta)
    H_vals.append(H_from_V(model, phi))

V_vals = np.array(V_vals)
eps_vals = np.array(eps_vals)
eta_vals = np.array(eta_vals)
H_vals = np.array(H_vals)

# %% [markdown]
# ### 6.3 L-BFGS plots Results
# ---

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle("Validation of the Learned Inflationary Potential", fontsize=15)
phi_vals = phi_vals.cpu().numpy()
# --- Potential ---
ax[0, 0].plot(phi_vals, V_vals, color='navy', lw=2)
ax[0, 0].set_xlabel(r"$\phi$")
ax[0, 0].set_ylabel(r"$V(\phi)$")
ax[0, 0].set_title("Learned inflationary potential")
#ax[0, 0].set_ylim(-1e-4, 1e-4)

# --- Epsilon ---
ax[0, 1].plot(phi_vals, eps_vals, color='darkred', lw=2)
ax[0, 1].axhline(1, color='gray', ls='--', lw=1)
ax[0, 1].set_xlabel(r"$\phi$")
ax[0, 1].set_ylabel(r"$\epsilon_V$")
ax[0, 1].set_title(r"Slow-roll parameter $\epsilon_V(\phi)$")

# --- Eta ---
ax[1, 0].plot(phi_vals, eta_vals, color='teal', lw=2)
ax[1, 0].axhline(0, color='gray', ls='--', lw=1)
ax[1, 0].set_xlabel(r"$\phi$")
ax[1, 0].set_ylabel(r"$\eta_V$")
ax[1, 0].set_title(r"Slow-roll parameter $\eta_V(\phi)$")

# --- H(φ) ---
ax[1, 1].plot(phi_vals, H_vals, color='orange', lw=2)
ax[1, 1].set_xlabel(r"$\phi$")
ax[1, 1].set_ylabel(r"$H(\phi)$")
ax[1, 1].set_title("Hubble scale during inflation")

for a in ax.flat:
    a.grid(True, ls=':')
plt.tight_layout()
plt.show()

# %% [markdown]
# # License and Terms of Use
# ---
# This code is distributed under the terms of the GNU General Public License (GPL).
# You are free to use, modify, and redistribute it, provided that any derivative work is released under the same license and that proper credit is given to the original author.
# The code is provided “as is”, without any warranty of any kind, express or implied.
